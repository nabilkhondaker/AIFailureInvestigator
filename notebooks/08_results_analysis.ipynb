# %% [markdown]
# # 08 — Results analysis
#
# Load metrics from `outputs/experiments/` after running experiment scripts. No hard-coded scores are stored in the repository.

# %%
from pathlib import Path
print('Experiment outputs:', list(Path('outputs/experiments').glob('**/*'))[:20])
